# %% [markdown]
# # Inference
#
# Demonstrate how one can fit a multi-wavelength set of lightcurves with SAJAX. Show examples of MCMC, variational inference, and basic gradient-descent techniques

# %% [markdown]
# # WIP
